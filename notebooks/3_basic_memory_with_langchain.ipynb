# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
prompts = [
    {"role":"user", "content":"hello, my name is prateek mishra"},
    {"role":"ai", "content":"Hello,  prateek mishra"},
    {"role":"user", "content":"what is my name"}
]

res = llm.invoke(prompts)

# %%
res.content
# Out:
# 'Your name is Prateek Mishra.'

# %% [markdown]
# #### Manage History

# %%
history =  [ ]

while True:
    query =input("User: ")
    if query.lower() in ["exit", "quit", "bye"]:
        print("Good bye have a nice day ")
        break

    history.append({"role":"user","content":query})
    print("User: ", query)

    res = llm.invoke(history)
    history.append({"role":"ai","content":res.content})
    print("AI: ", res.content, "\n")
# Out:
# User:  hello
# AI:  Hello! How can I help you today?
#
# User:  who is pm of india
# AI:  The current Prime Minister of India is **Narendra Modi**.
#
# User:  what is his age?
# AI:  Narendra Modi was born on **September 17, 1950**.
#
# To calculate his current age, you would subtract 1950 from the current year. As of today, in 2024, he would be **73 years old**.
#
# User:
# c:\Users\HP\Desktop\GENAI-Series\venv\Lib\site-packages\langchain_google_genai\chat_models.py:2858: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# AI:
