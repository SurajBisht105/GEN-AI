# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
# function for converting the output into upper case

def upper_case(result:str):
    return result.upper()

# %% [markdown]
# #### Prompts Templates - Dynamic Prompts

# %%
from langchain_core.prompts import ChatPromptTemplate

prompts = ChatPromptTemplate.from_messages([
    {"role":"system", "content":"You are a translator and translate input in {language}"},
    {"role":"user","content":"{query}"},
])

# %% [markdown]
# #### parser

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# %% [markdown]
# #### Chain

# %%
chain = prompts | llm | parser | upper_case

# %%
final_output = chain.invoke({"language":"Hinglish","query":"Hello how are you !"})

print(final_output)
# Out:
# NAMASTE, MAIN THEEK HOON. AAP KAISE HAIN?
