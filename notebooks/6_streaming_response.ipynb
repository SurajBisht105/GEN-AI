# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", streaming=True)

# %%
question = "can you explain me gen ai?"

# %%
response = llm.stream(question)

for chunk in response:
    print(chunk.content, end="")
# Out:
# Okay, let's break down Generative AI (Gen AI) in a way that's easy to understand.
#
# **Imagine a really creative and intelligent assistant.**
#
# That's essentially what Generative AI is. Instead of just *understanding* information and answering questions (like traditional AI), Gen AI can actually **create new content**. This content can be text, images, music, code, videos, and much more.
#
# **The Core Idea: Learning from the World and Making Something New**
#
# Think of it like this:
#
# 1.  **Learning:** Gen AI models are trained on massive amounts of data. For example:
#     *   **Text models** are trained on billions of words from books, articles, websites, and conversations.
#     *   **Image models** are trained on millions of images with their descriptions.
#     *   **Music models** are trained on vast libraries of songs.
#
# 2.  **Finding Patterns:** During this training, the AI doesn't just memorize. It learns the underlying patterns, structures, relationships, and styles within the data. It learns grammar, syntax, artistic styles, musical genres, coding logic, and so on.
#
# 3.  **Generating:** Once trained, the AI can use what it has learned to produce something entirely new. You give it a prompt (a request or instruction), and it uses its learned patterns to generate a response that fits your request.
#
# **Think of it like learning to cook:**
#
# *   **Traditional AI:** Might be able to tell you the ingredients and steps for a recipe (understanding and retrieving information).
# *   **Generative AI:** After studying thousands of recipes and tasting many dishes, it can invent a *new* recipe for you, based on your preferences (e.g., "I want a spicy vegetarian pasta dish").
#
# **Key Characteristics of Generative AI:**
#
# *   **Creativity:** It can produce novel outputs that weren't explicitly programmed.
# *   **Versatility:** It can work across different types of media (text, image, audio, etc.).
# *   **Adaptability:** It can learn and adapt to new styles and requests.
# *   **Scalability:** It can produce content much faster and at a larger scale than humans.
#
# **How it Works (Simplified):**
#
# While the underlying technology is complex (involving neural networks, deep learning, transformers, etc.), the core mechanism often involves:
#
# 1.  **Understanding the Prompt:** The AI analyzes your request to grasp the intent, keywords, and desired outcome.
# 2.  **Predicting the Next Element:** Based on its training data, it predicts what the "next best thing" should be. For text, this might be the next word. For images, it might be the next pixel or a set of pixels.
# 3.  **Iterative Generation:** It repeats this prediction process, building up the output piece by piece until it fulfills the prompt.
#
# **Examples of Generative AI in Action:**
#
# *   **Text Generation:**
#     *   Writing emails, articles, poems, stories.
#     *   Summarizing long documents.
#     *   Translating languages.
#     *   Answering complex questions.
#     *   Generating code snippets.
#     *   **Example:** ChatGPT, Bard (now Gemini)
#
# *   **Image Generation:**
#     *   Creating realistic or artistic images from text descriptions.
#     *   Editing existing images.
#     *   Generating logos or graphics.
#     *   **Example:** DALL-E, Midjourney, Stable Diffusion
#
# *   **Audio/Music Generation:**
#     *   Composing new music in various styles.
#     *   Generating realistic voiceovers.
#     *   Creating sound effects.
#
# *   **Video Generation:**
#     *   Creating short video clips from text prompts.
#     *   Animating still images.
#
# **Why is it a Big Deal?**
#
# Gen AI is revolutionary because it's democratizing creation. It allows individuals and businesses to:
#
# *   **Boost Productivity:** Automate tasks that used to take hours.
# *   **Spark Innovation:** Generate new ideas and explore creative possibilities.
# *   **Personalize Experiences:** Create tailored content for individuals.
# *   **Lower Barriers to Entry:** Make sophisticated content creation accessible to more people.
#
# **Important Considerations:**
#
# *   **Accuracy and Hallucinations:** Gen AI can sometimes "hallucinate" or make up information that isn't true. It's crucial to fact-check its outputs.
# *   **Bias:** The AI's outputs can reflect the biases present in its training data.
# *   **Ethics and Misuse:** There are concerns about plagiarism, deepfakes, and the spread of misinformation.
# *   **Copyright:** The legal implications of AI-generated content are still being worked out.
#
# **In a nutshell, Generative AI is a powerful tool that can create new things by learning from vast amounts of existing data. It's like having a super-powered creative partner that can bring your ideas to life in exciting new ways.**
